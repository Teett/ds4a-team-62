# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# We noticed some of the fields taken from the source had a decimal separator with ",". The way Pandas works it interpret the "." as decimal separators instead of ",", and that´s why we need to tell the pd.read_csv to take the decimals with "," to transform it into a format readable for Pandas

# %%
url = 'https://raw.githubusercontent.com/Teett/ds4a-team-62/main/data/raw/pluri_patients_2020.csv?token=GHSAT0AAAAAABUSH35VZ62L3AUK635ZJGLCYUM65XQ'
df = pd.read_csv(url, sep = ';', decimal = ",")
df.head()
# Out:
#    edad sexo  n_urg  n_hosp  n_cx  n_ce_med_general  n_ce_med_especializada  \
# 0    29    F      1       1     0                 3                       9
# 1    67    F      1       0     0                 0                       1
# 2    83    M      1       0     0                 4                       3
# 3    66    M      1       1     1                 0                       2
# 4    62    F      2       0     0                 2                       8
#
#    estancia_sala  estancia_uce  estancia_uci  ...  \
# 0              2             0             0  ...
# 1              0             0             0  ...
# 2              0             0             0  ...
# 3             13             0             0  ...
# 4              0             0             0  ...
#
#    tasa_de_filtración_glomerular_tfg  estadio_de_la_enfermedad_renal  \
# 0                                NaN                       Estadio 0
# 1                              60.13                       Estadio 2
# 2                                NaN                       Estadio 0
# 3                              58.09                      Estadio 3A
# 4                             107.76                       Estadio 1
#
#    microalbuminuria   tsh     clase_funcional  creatinina_2_consulta  \
# 0               NaN   NaN      No clasificado                    NaN
# 1              3.02  5.77  Clase funcional 2B                   0.86
# 2               NaN   NaN      No clasificado                    NaN
# 3              7.00  1.17   Clase funcional 4                   0.00
# 4             68.00  2.89  Clase funcional 2B                   0.00
#
#    tasa_de_filtración_glomerular_tfg3  cambio_de_tfg  úlcera_de_pie_diabético  \
# 0                                 NaN            NaN                       No
# 1                               60.13            0.0                       No
# 2                                 NaN            NaN                       No
# 3                                0.00            0.0                       No
# 4                                0.00            0.0                       No
#
#    estado_vital
# 0          vivo
# 1          vivo
# 2          vivo
# 3     fallecido
# 4          vivo
#
# [5 rows x 137 columns]

# %%
df.to_excel('BD Proyecto DS4A.xlsx')

# %%
analysis_list = ["edad",
"peso",
"talla",
"saturacion_oxigeno",
"perímetro_muslo",
"perímetro_cintura",
"pliegue_triceps",
"pliegue_abdomen",
"pliegue_muslo",
"presión_arterial_sistólica",
"presión_arterial_diastólica",
"frecuencia_cardíaca_en_reposo",
"auto-calificacion_nivel_de_ejercicio",
"constantes",
"mets_-índice_metabólico",
"vo2_-_máxima_cantidad_de_oxígeno",
"índice_de_fragilidad_groningen",
"calificacion_indicefragilidad",
"tiempo_segundos_monopodal",
"calificacion_apoyo_monopodal",
"tiempo_segundos_5metros",
"calificación_velocidad",
"indice_tobillo_brazo",
"diabetes_mellitus",
"tipo_diabetes_mellitus",
"es_insulinorequiriente",
"tiempo_con_el_diagnóstico",
"control_diabetes",
"tiene_hta",
"control_hta",
"tiempo_con_el_diagnóstico2",
"epoc_bodex",
"enfermedad_coronaria",
"insuficiencia_cardíaca",
"valvulopatía",
"arritmia_o_paciente_con_dispositivo",
"sufre_de_alguna_enfermedad_cardiovascular",
"tabaquismo",
"cuantos_cigarrillos_día",
"años_de_consumo",
"clasificación_de_framinghan",
"estadio_de_la_enfermedad_renal",
"clase_funcional",
"úlcera_de_pie_diabético"
]

# %%
df = df[analysis_list]
df.head()
# Out:
#    edad  peso  talla  saturacion_oxigeno  perímetro_muslo  perímetro_cintura  \
# 0    29   NaN    NaN                 NaN              NaN                NaN
# 1    67  60.0  149.0                96.0             54.0              101.0
# 2    83   NaN    NaN                 NaN              NaN                NaN
# 3    66  52.0  170.0                93.0             35.0               75.0
# 4    62  55.0  148.0                95.0             45.0               87.0
#
#    pliegue_triceps  pliegue_abdomen  pliegue_muslo  \
# 0              NaN              NaN            NaN
# 1             40.0             70.0           50.0
# 2              NaN              NaN            NaN
# 3              2.0              2.0            2.0
# 4              1.0             20.0           20.0
#
#    presión_arterial_sistólica  ...  valvulopatía  \
# 0                         NaN  ...            No
# 1                       125.0  ...            No
# 2                         NaN  ...            No
# 3                       110.0  ...            No
# 4                       135.0  ...            No
#
#    arritmia_o_paciente_con_dispositivo  \
# 0                                   No
# 1                                   No
# 2                                   No
# 3                                   No
# 4                                   Si
#
#    sufre_de_alguna_enfermedad_cardiovascular  tabaquismo  \
# 0                                         No          No
# 1                                         No          No
# 2                                         No          No
# 3                                         Si          No
# 4                                         Si          No
#
#    cuantos_cigarrillos_día  años_de_consumo  clasificación_de_framinghan  \
# 0                      NaN              NaN               No clasificado
# 1                      0.0              0.0                  Bajo riesgo
# 2                      NaN              NaN               No clasificado
# 3                      0.0              0.0                  Bajo riesgo
# 4                      0.0              NaN                  Alto riesgo
#
#   estadio_de_la_enfermedad_renal     clase_funcional úlcera_de_pie_diabético
# 0                      Estadio 0      No clasificado                      No
# 1                      Estadio 2  Clase funcional 2B                      No
# 2                      Estadio 0      No clasificado                      No
# 3                     Estadio 3A   Clase funcional 4                      No
# 4                      Estadio 1  Clase funcional 2B                      No
#
# [5 rows x 44 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5511 entries, 0 to 5510
# Data columns (total 44 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   edad                                       5511 non-null   int64
#  1   peso                                       4698 non-null   float64
#  2   talla                                      4698 non-null   float64
#  3   saturacion_oxigeno                         4682 non-null   float64
#  4   perímetro_muslo                            4698 non-null   float64
#  5   perímetro_cintura                          4698 non-null   float64
#  6   pliegue_triceps                            4698 non-null   float64
#  7   pliegue_abdomen                            4698 non-null   float64
#  8   pliegue_muslo                              4698 non-null   float64
#  9   presión_arterial_sistólica                 4698 non-null   float64
#  10  presión_arterial_diastólica                4698 non-null   float64
#  11  frecuencia_cardíaca_en_reposo              4698 non-null   float64
#  12  auto-calificacion_nivel_de_ejercicio       4698 non-null   float64
#  13  constantes                                 4698 non-null   float64
#  14  mets_-índice_metabólico                    4698 non-null   float64
#  15  vo2_-_máxima_cantidad_de_oxígeno           4698 non-null   float64
#  16  índice_de_fragilidad_groningen             4698 non-null   float64
#  17  calificacion_indicefragilidad              5511 non-null   object
#  18  tiempo_segundos_monopodal                  4698 non-null   float64
#  19  calificacion_apoyo_monopodal               5511 non-null   object
#  20  tiempo_segundos_5metros                    4698 non-null   float64
#  21  calificación_velocidad                     5511 non-null   object
#  22  indice_tobillo_brazo                       5511 non-null   object
#  23  diabetes_mellitus                          5511 non-null   object
#  24  tipo_diabetes_mellitus                     5511 non-null   object
#  25  es_insulinorequiriente                     5511 non-null   object
#  26  tiempo_con_el_diagnóstico                  1529 non-null   float64
#  27  control_diabetes                           5511 non-null   object
#  28  tiene_hta                                  5511 non-null   object
#  29  control_hta                                5511 non-null   object
#  30  tiempo_con_el_diagnóstico2                 2678 non-null   float64
#  31  epoc_bodex                                 5511 non-null   object
#  32  enfermedad_coronaria                       5511 non-null   object
#  33  insuficiencia_cardíaca                     5511 non-null   object
#  34  valvulopatía                               5511 non-null   object
#  35  arritmia_o_paciente_con_dispositivo        5511 non-null   object
#  36  sufre_de_alguna_enfermedad_cardiovascular  5511 non-null   object
#  37  tabaquismo                                 5511 non-null   object
#  38  cuantos_cigarrillos_día                    4351 non-null   float64
#  39  años_de_consumo                            4278 non-null   float64
#  40  clasificación_de_framinghan                5511 non-null   object
#  41  estadio_de_la_enfermedad_renal             5511 non-null   object
#  42  clase_funcional                            5511 non-null   object
#  43  úlcera_de_pie_diabético                    5511 non-null   object
# dtypes: float64(22), int64(1), object(21)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#               edad         peso        talla  saturacion_oxigeno  \
# count  5511.000000  4698.000000  4698.000000         4682.000000
# mean     72.040646    67.541954   156.294593          114.217642
# std      13.506609    15.094395     9.774183         1374.409912
# min      18.000000     0.000000     0.000000            0.000000
# 25%      65.000000    58.000000   150.000000           93.000000
# 50%      73.000000    67.000000   156.000000           95.000000
# 75%      81.000000    76.000000   162.000000           96.000000
# max     104.000000   157.000000   188.000000        94138.000000
#
#        perímetro_muslo  perímetro_cintura  pliegue_triceps  pliegue_abdomen  \
# count      4698.000000        4698.000000      4698.000000      4698.000000
# mean         47.177778          94.576948        17.061090        25.360622
# std          89.559566          18.904658        15.105935        82.401040
# min           0.000000           0.000000         0.000000         0.000000
# 25%          40.000000          86.000000        10.000000        10.000000
# 50%          47.000000          96.000000        15.000000        22.000000
# 75%          54.000000         106.000000        23.000000        35.000000
# max        6124.000000         150.000000       730.000000      5510.000000
#
#        pliegue_muslo  presión_arterial_sistólica  ...   constantes  \
# count    4698.000000                 4698.000000  ...  4698.000000
# mean       20.755236                  128.989996  ...     0.030692
# std        15.397757                   20.177668  ...     0.268260
# min         0.000000                   70.000000  ...     0.000000
# 25%        10.000000                  117.000000  ...     0.000000
# 50%        17.000000                  125.000000  ...     0.000000
# 75%        30.000000                  140.000000  ...     0.000000
# max        95.000000                  270.000000  ...     3.030000
#
#        mets_-índice_metabólico  vo2_-_máxima_cantidad_de_oxígeno  \
# count              4698.000000                       4698.000000
# mean                -22.267468                        -77.936136
# std                1860.117029                       6510.409603
# min             -127491.080000                    -446218.780000
# 25%                   3.196075                         11.186225
# 50%                   4.604850                         16.116950
# 75%                   6.436875                         22.529025
# max                  14.174100                         49.609300
#
#        índice_de_fragilidad_groningen  tiempo_segundos_monopodal  \
# count                     4698.000000                4698.000000
# mean                         4.805875                   7.356535
# std                          3.492653                  10.125167
# min                          0.000000                   0.000000
# 25%                          1.000000                   0.000000
# 50%                          4.000000                   2.000000
# 75%                          8.000000                  15.000000
# max                         15.000000                 210.000000
#
#        tiempo_segundos_5metros  tiempo_con_el_diagnóstico  \
# count              4698.000000                1529.000000
# mean                  4.393572                  14.328973
# std                   3.026154                  52.225432
# min                   0.000000                   0.000000
# 25%                   0.000000                   5.000000
# 50%                   5.000000                  10.000000
# 75%                   6.000000                  20.000000
# max                   9.000000                2020.000000
#
#        tiempo_con_el_diagnóstico2  cuantos_cigarrillos_día  años_de_consumo
# count                 2678.000000              4351.000000      4278.000000
# mean                    16.572069                 1.787175         3.619448
# std                     44.340321                 6.197792        11.483308
# min                      0.000000                 0.000000         0.000000
# 25%                     10.000000                 0.000000         0.000000
# 50%                     15.000000                 0.000000         0.000000
# 75%                     20.000000                 0.000000         0.000000
# max                   2020.000000                60.000000        90.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# Looking into the data we can see some low values for size and weight. Howevever, this could be derived from a medical condition or a very sick patient, also very high values for weight which could be an overweighted patient, therefore we will need to analyze both scenarios separately, for low and high values.

# %% [markdown]
# There are some points at "zero" which need to be deleted as there is no such person with size and weight equals to zero. Also there is one patient with "saturación de oxigeno" which is the percentage of hemoglobine in the blood on 0%. Therefore this could be a bad reading as normal values vary between 90% to 100%.
#
# Also, there are some patients with a Heart Rate of 2 which will means it has 2 beats per minute, and it´s not possible or the person will be dead.
#
# These cases could have more valuable information for other variables so we will not exlude them, instead we are going to replace the outliers values with nan.

# %%
axes = df.boxplot(column = 'frecuencia_cardíaca_en_reposo')
axes.set_title('Resting Heart Rate');

# %%
df['frecuencia_cardíaca_en_reposo'].sort_values(ascending = True)
# Out:
# 3089     2.0
# 275     40.0
# 2825    40.0
# 896     40.0
# 4101    40.0
#         ...
# 5474     NaN
# 5484     NaN
# 5487     NaN
# 5488     NaN
# 5494     NaN
# Name: frecuencia_cardíaca_en_reposo, Length: 5511, dtype: float64

# %%
axes = df.boxplot(column = ['peso','talla'])
axes.set_title('Weight(Kg) and Size(cm)');

# %%
df[['edad','peso']].sort_values(by = 'peso', ascending = True).head(10)
# Out:
#       edad  peso
# 3782    85   0.0
# 254     70  14.5
# 730     32  23.0
# 4400    23  24.8
# 1944    24  28.0
# 151     48  28.0
# 5190    25  29.0
# 773     84  29.0
# 4139    81  29.0
# 5098    25  30.0

# %%
axes = df.boxplot(column = 'saturacion_oxigeno')
axes.set_title('Oxygen Saturation');

# %% [markdown]
# Oxygen Saturation is a percentage that goes from 0 to 100%. Therefore the we will replace those upper outliers with nan

# %%
df['saturacion_oxigeno'].min(), df['saturacion_oxigeno'].max()
# Out:
# (0.0, 94138.0)

# %% [markdown]
# Doing data cleaning:

# %%
df['talla'] = df['talla'].replace({0:np.nan})
df[df['frecuencia_cardíaca_en_reposo'] < 40] = np.nan #Replacing outliers less than 40
# beats per minute with nan values.
df[df['peso'] < 20] = np.nan #Removing outliers that are weights less than 20kg
df[df['saturacion_oxigeno'] > 100] = np.nan #max value should be 100%
df['saturacion_oxigeno'] = df['saturacion_oxigeno'].replace({0:np.nan})

# %%
axes = df.boxplot(column = 'frecuencia_cardíaca_en_reposo')
axes.set_title('Resting Heart Rate');

# %%
axes = df.boxplot(column = ['peso','talla'])
axes.set_title('Weight(Kg) and Size(cm)');
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
axes = df.boxplot(column = 'saturacion_oxigeno')
axes.set_title('Oxygen Saturation');

# %% [markdown]
# Normal Values of Oxygen Saturation are between 90% to 100%, however we will keep those lower values as could be patients with some affections to be analyzed.
#
# Now that we have a cleaner dataset, we will continue exploring:

# %%
df.describe()
# Out:
#               edad         peso        talla  saturacion_oxigeno  \
# count  5507.000000  4694.000000  4693.000000         4677.000000
# mean     72.040857    67.570217   156.363307           94.150096
# std      13.507930    15.043310     9.228943            3.336959
# min      18.000000    23.000000    64.000000           65.000000
# 25%      65.000000    58.000000   150.000000           93.000000
# 50%      73.000000    67.000000   156.000000           95.000000
# 75%      81.000000    76.000000   162.000000           96.000000
# max     104.000000   157.000000   188.000000          100.000000
#
#        perímetro_muslo  perímetro_cintura  pliegue_triceps  pliegue_abdomen  \
# count      4694.000000        4694.000000      4694.000000      4694.000000
# mean         47.187516          94.599169        17.054751        25.356029
# std          89.594230          18.851733        15.099503        82.432501
# min           0.000000           0.000000         0.000000         0.000000
# 25%          40.000000          86.000000        10.000000        10.000000
# 50%          47.000000          96.000000        15.000000        22.000000
# 75%          54.000000         106.000000        23.000000        35.000000
# max        6124.000000         150.000000       730.000000      5510.000000
#
#        pliegue_muslo  presión_arterial_sistólica  ...   constantes  \
# count    4694.000000                 4694.000000  ...  4694.000000
# mean       20.752684                  128.993822  ...     0.030718
# std        15.393215                   20.181389  ...     0.268373
# min         0.000000                   70.000000  ...     0.000000
# 25%        10.000000                  117.000000  ...     0.000000
# 50%        17.000000                  125.000000  ...     0.000000
# 75%        30.000000                  140.000000  ...     0.000000
# max        95.000000                  270.000000  ...     3.030000
#
#        mets_-índice_metabólico  vo2_-_máxima_cantidad_de_oxígeno  \
# count              4694.000000                       4694.000000
# mean                -22.292369                        -78.023293
# std                1860.909382                       6513.182836
# min             -127491.080000                    -446218.780000
# 25%                   3.196075                         11.186225
# 50%                   4.604500                         16.115750
# 75%                   6.433375                         22.516800
# max                  14.174100                         49.609300
#
#        índice_de_fragilidad_groningen  tiempo_segundos_monopodal  \
# count                     4694.000000                4694.000000
# mean                         4.803792                   7.362804
# std                          3.490460                  10.127202
# min                          0.000000                   0.000000
# 25%                          1.000000                   0.000000
# 50%                          4.000000                   2.000000
# 75%                          8.000000                  15.000000
# max                         15.000000                 210.000000
#
#        tiempo_segundos_5metros  tiempo_con_el_diagnóstico  \
# count              4694.000000                1528.000000
# mean                  4.395824                  14.336387
# std                   3.026010                  52.241725
# min                   0.000000                   0.000000
# 25%                   0.000000                   5.000000
# 50%                   5.000000                  10.000000
# 75%                   6.000000                  20.000000
# max                   9.000000                2020.000000
#
#        tiempo_con_el_diagnóstico2  cuantos_cigarrillos_día  años_de_consumo
# count                 2675.000000              4347.000000      4274.000000
# mean                    16.580561                 1.786519         3.609967
# std                     44.364200                 6.199214        11.461357
# min                      0.000000                 0.000000         0.000000
# 25%                     10.000000                 0.000000         0.000000
# 50%                     15.000000                 0.000000         0.000000
# 75%                     20.000000                 0.000000         0.000000
# max                   2020.000000                60.000000        90.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# There are some variables that have a big difference between the 3rd Quartile and the Max, therefore we will see percentile 90 for all the variables.

# %%
df.quantile(.9)
# Out:
# edad                                     88.00000
# peso                                     87.00000
# talla                                   168.00000
# saturacion_oxigeno                       98.00000
# perímetro_muslo                          59.00000
# perímetro_cintura                       115.00000
# pliegue_triceps                          30.70000
# pliegue_abdomen                          45.00000
# pliegue_muslo                            45.00000
# presión_arterial_sistólica              156.00000
# presión_arterial_diastólica              87.00000
# frecuencia_cardíaca_en_reposo            91.00000
# auto-calificacion_nivel_de_ejercicio      1.00000
# constantes                                0.00000
# mets_-índice_metabólico                   7.84103
# vo2_-_máxima_cantidad_de_oxígeno         27.44357
# índice_de_fragilidad_groningen            9.00000
# tiempo_segundos_monopodal                25.00000
# tiempo_segundos_5metros                   9.00000
# tiempo_con_el_diagnóstico                25.00000
# tiempo_con_el_diagnóstico2               27.00000
# cuantos_cigarrillos_día                   5.00000
# años_de_consumo                          10.00000
# Name: 0.9, dtype: float64

# %% [markdown]
# We see some big differences between percentile 90 and the max for: perímetro_muslo, pliegue_triceps, pliegue_abdomen, tiempo_segundos_monopodal, tiempo_en_el_diagnostico and años_de_consumo so we are gonna look deeper if this is due to outliers that need to be removed as well

# %%
df['tiempo_con_el_diagnóstico'].sort_values(ascending = False)
# Out:
# 3792    2020.0
# 4476      60.0
# 1919      56.0
# 1643      50.0
# 1261      50.0
#          ...
# 5506       NaN
# 5507       NaN
# 5508       NaN
# 5509       NaN
# 5510       NaN
# Name: tiempo_con_el_diagnóstico, Length: 5511, dtype: float64

# %%
df['tiempo_con_el_diagnóstico2'].sort_values(ascending = False)
# Out:
# 3792    2020.0
# 620     1020.0
# 3975      60.0
# 1365      54.0
# 4084      51.0
#          ...
# 5501       NaN
# 5505       NaN
# 5506       NaN
# 5509       NaN
# 5510       NaN
# Name: tiempo_con_el_diagnóstico2, Length: 5511, dtype: float64

# %% [markdown]
# We have very clear outliers to eliminate here

# %%
df[df['tiempo_con_el_diagnóstico']>100] = np.nan
df[df['tiempo_con_el_diagnóstico2']>100] = np.nan
df['tiempo_con_el_diagnóstico'].max(),df['tiempo_con_el_diagnóstico2'].max()
# Out:
# (60.0, 60.0)

# %% [markdown]
# Continue with the rest of variables:

# %%
df['started_consuming'] = df['edad'] - df['años_de_consumo']
df[['edad','años_de_consumo','started_consuming']].sort_values(by = 'años_de_consumo',ascending = False).head(10)
# Out:
#        edad  años_de_consumo  started_consuming
# 4299   85.0             90.0               -5.0
# 5268   92.0             80.0               12.0
# 4904   84.0             72.0               12.0
# 2345   81.0             70.0               11.0
# 4777   85.0             70.0               15.0
# 993    84.0             70.0               14.0
# 2365   94.0             70.0               24.0
# 4772   84.0             70.0               14.0
# 3172   85.0             70.0               15.0
# 1660  101.0             70.0               31.0

# %%
df[df['started_consuming']<10][['edad','años_de_consumo','started_consuming']]
# Out:
#       edad  años_de_consumo  started_consuming
# 3285  65.0             58.0                7.0
# 4299  85.0             90.0               -5.0
# 5199  74.0             68.0                6.0
# 5226  68.0             60.0                8.0
# 5294  73.0             65.0                8.0

# %% [markdown]
# We created another column call "started_consuming" to understand according to the data at what age did the person start to consume tobacco. We found some discrepancies as a negative age (year of consumption are higher that the age) and also some information that say that some patients started consuming tobacco with less than 10 years old, which is very unlikely. For that reason, we will remove the age of consumption (años_de_consumo) for those patients from our dataset.

# %%
index_list = (df[df['started_consuming']<10]['años_de_consumo'].index)
index_list
# Out:
# Int64Index([3285, 4299, 5199, 5226, 5294], dtype='int64')

# %%
df['años_de_consumo'].iloc[index_list] = np.nan
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df[df['started_consuming']<10][['edad','años_de_consumo','started_consuming']]
# Out:
#       edad  años_de_consumo  started_consuming
# 3285  65.0              NaN                7.0
# 4299  85.0              NaN               -5.0
# 5199  74.0              NaN                6.0
# 5226  68.0              NaN                8.0
# 5294  73.0              NaN                8.0

# %% [markdown]
# Let´s continue with the last two variables of anaylis:

# %%
axes = df.boxplot(column = 'perímetro_muslo')
axes.set_title('Thigh perimeter');

# %%
df['perímetro_muslo'].sort_values(ascending=False)
# Out:
# 1937    6124.0
# 2140     251.0
# 629      125.0
# 2055     100.0
# 2076      95.0
#          ...
# 5474       NaN
# 5484       NaN
# 5487       NaN
# 5488       NaN
# 5494       NaN
# Name: perímetro_muslo, Length: 5511, dtype: float64

# %% [markdown]
# Values higher than 200 mm are not that normal, se cleaned it out:
#
# Source: https://scialert.net/fulltext/?doi=pjbs.2019.168.173#:~:text=The%20visceral%20fat%20area%20considered,female%20was%20considered%20as%20normal.

# %%
df[df['perímetro_muslo'] > 200] = np.nan
axes = df.boxplot(column = 'perímetro_muslo')
axes.set_title('Thigh perimeter');

# %%
axes = df.boxplot(column = ['pliegue_triceps','pliegue_abdomen'])
axes.set_title(' Triceps Fold (mm) and Abdomen Fold(mm)');

# %%
df['pliegue_triceps'].sort_values(ascending=False).head(10)
# Out:
# 980     730.0
# 236     125.0
# 838      95.0
# 1948     80.0
# 2609     75.0
# 2770     70.0
# 4836     66.0
# 586      65.0
# 5260     65.0
# 72       60.0
# Name: pliegue_triceps, dtype: float64

# %%
df['pliegue_abdomen'].sort_values(ascending=False).head(10)
# Out:
# 2600    5510.0
# 543      550.0
# 926      525.0
# 2304     225.0
# 3515     113.0
# 1109     106.0
# 3424     100.0
# 745       93.0
# 5146      90.0
# 417       90.0
# Name: pliegue_abdomen, dtype: float64

# %% [markdown]
# Values outside the normal range. For Abdomen more than 100 for male and more than 80 for female. Value over 120 will be changed to nan
#
# More info here:
#
# https://scialert.net/fulltext/?doi=pjbs.2019.168.173#:~:text=The%20visceral%20fat%20area%20considered,female%20was%20considered%20as%20normal.
#
# Regarding the Triceps Fold, for Boys and Girls is normal to be 30 mm or less, so for an adult person can be even higher. Folds higher than 80 mm will be turned into nan.
#
# Source: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5083983/

# %%
df[df['pliegue_triceps']>80] = np.nan
df[df['pliegue_abdomen'] > 120] = np.nan

# %%
axes = df.boxplot(column = ['pliegue_triceps','pliegue_abdomen'])
axes.set_title(' Triceps Fold (mm) and Abdomen Fold(mm)');
